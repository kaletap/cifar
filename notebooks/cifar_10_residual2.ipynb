# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 17 12:01:13 2017
@author: abhijeet
"""

import tensorflow.keras as keras
import tensorflow as tf
import numpy as np
import os

# %% [markdown]
# ## Functions

# %%
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    elif epoch > 100:
        lrate = 0.0003        
    return lrate

# %% [markdown]
# ## Data load and preproccess

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

num_classes = 10
y_train = keras.utils.to_categorical(y_train,num_classes)
y_test = keras.utils.to_categorical(y_test,num_classes)

# %% [markdown]
# ## Model architecture

# %%
weight_decay = 1e-4

inputs = keras.layers.Input(shape=x_train.shape[1:])
block_one = keras.layers.Conv2D(32, (3,3), padding='same', kernel_regularizer=keras.regularizers.l2(weight_decay))(inputs)
block_one = keras.layers.Activation('elu')(block_one)
block_one1 = keras.layers.BatchNormalization()(block_one)
block_one = keras.layers.Conv2D(32, (3,3), padding='same', kernel_regularizer=keras.regularizers.l2(weight_decay))(block_one1)
block_one = keras.layers.Activation('elu')(block_one)
block_one = keras.layers.BatchNormalization()(block_one)
block_one = keras.layers.MaxPooling2D(pool_size=(2,2))(block_one)
block_one = keras.layers.Dropout(0.2)(block_one)

resize_b1 = keras.layers.MaxPooling2D(pool_size=(2,2))(block_one1)

block_two = keras.layers.concatenate([resize_b1, block_one])
block_two = keras.layers.Conv2D(64, (3,3), padding='same', kernel_regularizer=keras.regularizers.l2(weight_decay))(block_two)
block_two = keras.layers.Activation('elu')(block_two)
block_two1 = keras.layers.BatchNormalization()(block_two)
block_two = keras.layers.Conv2D(64, (3,3), padding='same', kernel_regularizer=keras.regularizers.l2(weight_decay))(block_two1)
block_two = keras.layers.Activation('elu')(block_two)
block_two = keras.layers.BatchNormalization()(block_two)
block_two = keras.layers.MaxPooling2D(pool_size=(2,2))(block_two)
block_two = keras.layers.Dropout(0.3)(block_two)

resize_b12 = keras.layers.MaxPooling2D(pool_size=(2,2))(resize_b1)
resize_b2 = keras.layers.MaxPooling2D(pool_size=(2,2))(block_two1)

block_three = keras.layers.concatenate([resize_b12, resize_b2, block_two])
block_three = keras.layers.Conv2D(128, (3,3), padding='same', kernel_regularizer=keras.regularizers.l2(weight_decay))(block_three)
block_three = keras.layers.Activation('elu')(block_three)
block_three = keras.layers.BatchNormalization()(block_three)
block_three = keras.layers.Conv2D(128, (3,3), padding='same', kernel_regularizer=keras.regularizers.l2(weight_decay))(block_three)
block_three = keras.layers.Activation('elu')(block_three)
block_three = keras.layers.BatchNormalization()(block_three)
block_three = keras.layers.MaxPooling2D(pool_size=(2,2))(block_three)
block_three = keras.layers.Dropout(0.4)(block_three)


long_leap = keras.layers.MaxPooling2D(pool_size=(2,2))(resize_b1)
long_leap = keras.layers.Flatten()(long_leap)
long_leap = keras.layers.Dense(100)(long_leap)

flat = keras.layers.Flatten()(block_three)
flat = keras.layers.concatenate([long_leap, flat])
out = keras.layers.Dense(100)(flat)
out = keras.layers.Dense(10, activation='softmax')(out)

model = keras.models.Model(inputs=inputs, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 32)   128         activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 64)   0           max_pooling2d_1[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   36928       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 64)   256         activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 32)     0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 64)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 160)    0           max_pooling2d_3[0][0]
#                                                                  max_pooling2d_4[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 128)    184448      concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 128)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 128)    512         activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 128)    147584      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 128)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 32)     0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 4, 4, 128)    0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          204900      flatten[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2148)         0           dense[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          214900      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1010        dense_1[0][0]
# ==================================================================================================
# Total params: 838,634
# Trainable params: 837,738
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %% [markdown]
# ## Data augumentation

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
datagen.fit(x_train)

# %% [markdown]
# ## Callbacks

# %%
run_path = "/content/drive/My Drive/Colab Notebooks/mgu/model_res3"
mcp_save = keras.callbacks.ModelCheckpoint(os.path.join(run_path, 'model-{epoch:03d}-{accuracy:03f}-{val_accuracy:03f}.h5'),
                           save_best_only=True, monitor='val_accuracy')
# callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule), mcp_save]
callbacks = [mcp_save]

# %% [markdown]
# ## Training

# %%
batch_size = 64
opt_rms = keras.optimizers.RMSprop(lr=0.00001,decay=1e-6)
# model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
model.load_weights("/content/drive/My Drive/Colab Notebooks/mgu/model_res3/model-095-0.909664-0.890200.h5")
model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=125,\
                    verbose=1,validation_data=(x_test,y_test), callbacks=callbacks)
#save to disk
model_json = model.to_json()
with open('/content/drive/My Drive/Colab Notebooks/mgu/models/model.json', 'w') as json_file:
    json_file.write(model_json)
# Out:
# Epoch 1/125
# 781/781 [==============================] - 45s 57ms/step - loss: 0.4860 - accuracy: 0.8853 - val_loss: 0.5654 - val_accuracy: 0.8761
# Epoch 2/125
# 781/781 [==============================] - 43s 56ms/step - loss: 0.5053 - accuracy: 0.8831 - val_loss: 0.6090 - val_accuracy: 0.8613
# Epoch 3/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5091 - accuracy: 0.8812 - val_loss: 0.5744 - val_accuracy: 0.8671
# Epoch 4/125
# 781/781 [==============================] - 43s 56ms/step - loss: 0.5191 - accuracy: 0.8797 - val_loss: 0.6605 - val_accuracy: 0.8499
# Epoch 5/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5194 - accuracy: 0.8814 - val_loss: 0.6500 - val_accuracy: 0.8585
# Epoch 6/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5243 - accuracy: 0.8817 - val_loss: 0.6304 - val_accuracy: 0.8556
# Epoch 7/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5323 - accuracy: 0.8800 - val_loss: 0.7538 - val_accuracy: 0.8321
# Epoch 8/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5261 - accuracy: 0.8830 - val_loss: 0.7065 - val_accuracy: 0.8431
# Epoch 9/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5311 - accuracy: 0.8813 - val_loss: 0.6365 - val_accuracy: 0.8614
# Epoch 10/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5338 - accuracy: 0.8806 - val_loss: 0.6129 - val_accuracy: 0.8670
# Epoch 11/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5333 - accuracy: 0.8831 - val_loss: 0.6417 - val_accuracy: 0.8624
# Epoch 12/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5322 - accuracy: 0.8824 - val_loss: 0.6478 - val_accuracy: 0.8578
# Epoch 13/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5356 - accuracy: 0.8827 - val_loss: 0.6624 - val_accuracy: 0.8611
# Epoch 14/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5379 - accuracy: 0.8813 - val_loss: 0.7001 - val_accuracy: 0.8454
# Epoch 15/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5395 - accuracy: 0.8827 - val_loss: 0.6046 - val_accuracy: 0.8734
# Epoch 16/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5377 - accuracy: 0.8833 - val_loss: 0.6283 - val_accuracy: 0.8670
# Epoch 17/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5397 - accuracy: 0.8818 - val_loss: 0.6052 - val_accuracy: 0.8698
# Epoch 18/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5361 - accuracy: 0.8818 - val_loss: 0.6793 - val_accuracy: 0.8520
# Epoch 19/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5428 - accuracy: 0.8816 - val_loss: 0.6768 - val_accuracy: 0.8509
# Epoch 20/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5385 - accuracy: 0.8834 - val_loss: 0.6275 - val_accuracy: 0.8699
# Epoch 21/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5365 - accuracy: 0.8833 - val_loss: 0.7001 - val_accuracy: 0.8450
# Epoch 22/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5378 - accuracy: 0.8823 - val_loss: 0.5902 - val_accuracy: 0.8706
# Epoch 23/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5431 - accuracy: 0.8820 - val_loss: 0.6122 - val_accuracy: 0.8687
# Epoch 24/125
# 781/781 [==============================] - 42s 53ms/step - loss: 0.5366 - accuracy: 0.8826 - val_loss: 0.6491 - val_accuracy: 0.8589
# Epoch 25/125
# 781/781 [==============================] - 42s 53ms/step - loss: 0.5387 - accuracy: 0.8850 - val_loss: 0.5865 - val_accuracy: 0.8751
# Epoch 26/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5367 - accuracy: 0.8844 - val_loss: 0.5964 - val_accuracy: 0.8733
# Epoch 27/125
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5379 - accuracy: 0.8832 - val_loss: 0.6732 - val_accuracy: 0.8565
# Epoch 28/125
# 781/781 [==============================] - 42s 53ms/step - loss: 0.5426 - accuracy: 0.8812 - val_loss: 0.6645 - val_accuracy: 0.8601
# Epoch 29/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5384 - accuracy: 0.8819 - val_loss: 0.7061 - val_accuracy: 0.8471
# Epoch 30/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5398 - accuracy: 0.8831 - val_loss: 0.5834 - val_accuracy: 0.8782
# Epoch 31/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5295 - accuracy: 0.8874 - val_loss: 0.6614 - val_accuracy: 0.8599
# Epoch 32/125
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5387 - accuracy: 0.8842 - val_loss: 0.5721 - val_accuracy: 0.8797
# Epoch 33/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5371 - accuracy: 0.8840 - val_loss: 0.6008 - val_accuracy: 0.8727
# Epoch 34/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5380 - accuracy: 0.8826 - val_loss: 0.6195 - val_accuracy: 0.8705
# Epoch 35/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5328 - accuracy: 0.8852 - val_loss: 0.6250 - val_accuracy: 0.8654
# Epoch 36/125
# 781/781 [==============================] - 41s 52ms/step - loss: 0.5324 - accuracy: 0.8863 - val_loss: 0.5949 - val_accuracy: 0.8743
# Epoch 37/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5341 - accuracy: 0.8853 - val_loss: 0.6798 - val_accuracy: 0.8525
# Epoch 38/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5368 - accuracy: 0.8846 - val_loss: 0.6363 - val_accuracy: 0.8633
# Epoch 39/125
# 781/781 [==============================] - 42s 53ms/step - loss: 0.5332 - accuracy: 0.8852 - val_loss: 0.5887 - val_accuracy: 0.8751
# Epoch 40/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5321 - accuracy: 0.8843 - val_loss: 0.7002 - val_accuracy: 0.8528
# Epoch 41/125
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5301 - accuracy: 0.8852 - val_loss: 0.5885 - val_accuracy: 0.8745
# Epoch 42/125
# 781/781 [==============================] - 42s 53ms/step - loss: 0.5373 - accuracy: 0.8830 - val_loss: 0.6651 - val_accuracy: 0.8578
# Epoch 43/125
# 336/781 [===========>..................] - ETA: 21s - loss: 0.5280 - accuracy: 0.8862

# %% [markdown]
# ## Testing

# %%
scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
